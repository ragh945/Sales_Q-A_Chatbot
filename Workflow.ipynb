# %% [markdown]
# # **Sales Q&A Chatbot (POC)** – Task
#
# - **Ask Questions**: Users can type sales-related questions in plain English.
#
# - **Generate SQL**: Chatbot automatically converts questions into valid SQL queries.
#
# - **Run Queries**: Executes SQL queries on the AdventureWorks Sales database.
#
# - **Display Results**: Shows the query results in a table.
#
# - **Summarize Data**: Provides a short textual summary of the results.
#
# - **Keep History**: Maintains chat history for reference and follow-up questions.

# %% [markdown]
# # Libararies
# - **streamlit** :To build interactive web apps for data science and machine learning
# - **langchain**:LangChain is a Python framework for building applications that use Large Language Models (LLMs). It provides tools to connect LLMs to prompts, chains, agents, and external data sources (like databases, APIs, or files
# - **os** : Python built-in library for interacting with the operating system.
# - **re** :Matching Ptterns from extracted text.
# - **dotenv**:load environment variables from a .env file.(API Keys securely)
# - **pandas**:Data Analysis and Manipulation.
# - **pyodbc**:Python library to connect and interact with ODBC databases.
# - **langchain_google_genai.ChatGoogleGenerativeAI** :Use Gemini models via Langchain.
# - **langchain.prompts.PromptTemplate** : Structuring the prompt to include variables.
# - **langchain.chains.LLMChain** : Connects Prompt+LLM+Input

# %% [markdown]
# # Workflow
# ![flow2.png](attachment:flow2.png)

# %% [markdown]
# | TABLE_SCHEMA | TABLE_NAME       | COLUMN_NAME                                |
# | ------------ | ---------------- | ------------------------------------------ |
# | Sales        | Customer         | CustomerID, PersonID, StoreID, ...         |
# | Person       | Person           | BusinessEntityID, FirstName, LastName, ... |
# | Sales        | SalesOrderHeader | SalesOrderID, OrderDate, CustomerID, ...   |

# %% [markdown]
# Use the following schemas and tables with columns:
# - Sales.Customer (CustomerID, PersonID, StoreID, TerritoryID, AccountNumber, rowguid, ModifiedDate)
# - Person.Person (BusinessEntityID, PersonType, NameStyle, Title, FirstName, MiddleName, LastName, Suffix, EmailPromotion, - AdditionalContactInfo, Demographics, rowguid, ModifiedDate)
# - Sales.SalesOrderHeader (SalesOrderID, RevisionNumber, OrderDate, DueDate, ShipDate, Status, OnlineOrderFlag, - - - - - SalesOrderNumber, PurchaseOrderNumber, AccountNumber, CustomerID, SalesPersonID, TerritoryID, BillToAddressID, ShipToAddressID, ShipMethodID, CreditCardID, CreditCardApprovalCode, CurrencyRateID, SubTotal, TaxAmt, Freight, TotalDue, Comment, rowguid, ModifiedDate)
# ...
# (more tables continue here)
